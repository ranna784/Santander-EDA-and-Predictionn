# %% [markdown]
# ### Content:

# %% [markdown]
# #### * introduction

# %% [markdown]
# ##### * Prepare the data analysis

# %% [markdown]
# #### * Data exploration:
#     * Check the data
#     * Density plots of features
#     * Distribution of mean and std
#     * Distribution of min and max
#     * Distribution of skew and kurtosis
#     * Features correlations.
#     * Duplicated values

# %% [markdown]
# * Feature engineering

# %% [markdown]
# * Model

# %% [markdown]
# * Submission
# * References

# %% [markdown]
# ##### Load Packages:

# %%
import gc
import os
import logging
import datetime
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import lightgbm as lgb
from tqdm import tqdm_notebook
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn.metrics import roc_auc_score,roc_curve
from sklearn.model_selection import StratifiedKFold
warnings.filterwarnings('ignore')

# %% [markdown]
# ##### Load The Data:

# %%
train_df = pd.read_csv("train.csv")
test_df = pd.read_csv("test.csv")

# %% [markdown]
# ##### Data Exploration:

# %%
train_df.shape,test_df.shape
# Out:
# ((200000, 202), (200000, 201))

# %% [markdown]
# ##### Both the train and test data have 200,000 entries and 202,respectivelly 201 columns.

# %%
train_df.head()
# Out:
#    ID_code  target    var_0   var_1    var_2   var_3    var_4   var_5   var_6  \
# 0  train_0       0   8.9255 -6.7863  11.9081  5.0930  11.4607 -9.2834  5.1187
# 1  train_1       0  11.5006 -4.1473  13.8588  5.3890  12.3622  7.0433  5.6208
# 2  train_2       0   8.6093 -2.7457  12.0805  7.8928  10.5825 -9.0837  6.9427
# 3  train_3       0  11.0604 -2.1518   8.9522  7.1957  12.5846 -1.8361  5.8428
# 4  train_4       0   9.8369 -1.4834  12.8746  6.6375  12.2772  2.4486  5.9405
#
#      var_7  ...  var_190  var_191  var_192  var_193  var_194  var_195  \
# 0  18.6266  ...   4.4354   3.9642   3.1364   1.6910  18.5227  -2.3978
# 1  16.5338  ...   7.6421   7.7214   2.5837  10.9516  15.4305   2.0339
# 2  14.6155  ...   2.9057   9.7905   1.6704   1.6858  21.6042   3.1417
# 3  14.9250  ...   4.4666   4.7433   0.7178   1.4214  23.0347  -1.2706
# 4  19.2514  ...  -1.4905   9.5214  -0.1508   9.1942  13.2876  -1.5121
#
#    var_196  var_197  var_198  var_199
# 0   7.8784   8.5635  12.7803  -1.0914
# 1   8.1267   8.7889  18.3560   1.9518
# 2  -6.5213   8.2675  14.7222   0.3965
# 3  -2.9275  10.2922  17.9697  -8.9996
# 4   3.9267   9.5031  17.9974  -8.8104
#
# [5 rows x 202 columns]

# %%
test_df.head()
# Out:
#   ID_code    var_0    var_1    var_2   var_3    var_4   var_5   var_6  \
# 0  test_0  11.0656   7.7798  12.9536  9.4292  11.4327 -2.3805  5.8493
# 1  test_1   8.5304   1.2543  11.3047  5.1858   9.1974 -4.0117  6.0196
# 2  test_2   5.4827 -10.3581  10.1407  7.0479  10.2628  9.8052  4.8950
# 3  test_3   8.5374  -1.3222  12.0220  6.5749   8.8458  3.1744  4.9397
# 4  test_4  11.7058  -0.1327  14.1295  7.7506   9.1035 -8.5848  6.8595
#
#      var_7   var_8  ...  var_190  var_191  var_192  var_193  var_194  var_195  \
# 0  18.2675  2.1337  ...  -2.1556  11.8495  -1.4300   2.4508  13.7112   2.4669
# 1  18.6316 -4.4131  ...  10.6165   8.8349   0.9403  10.1282  15.5765   0.4773
# 2  20.2537  1.5233  ...  -0.7484  10.9935   1.9803   2.1800  12.9813   2.1281
# 3  20.5660  3.3755  ...   9.5702   9.0766   1.6580   3.5813  15.1874   3.1656
# 4  10.6048  2.9890  ...   4.2259   9.1723   1.2835   3.3778  19.5542  -0.2860
#
#    var_196  var_197  var_198  var_199
# 0   4.3654  10.7200  15.4722  -8.7197
# 1  -1.4852   9.8714  19.1293 -20.9760
# 2  -7.1086   7.0618  19.8956 -23.1794
# 3   3.9567   9.2295  13.0168  -4.2108
# 4  -5.1612   7.2882  13.9260  -9.1846
#
# [5 rows x 201 columns]

# %% [markdown]
# Train Contains:
#     * ID_code(string);
#     * Target;
#     * 200 numerical variables,named for var_0 to var_199;

# %% [markdown]
# Test Contains:
#     * ID_code(string);
#     * 200 Numerical variables,named from var_0 to var_199;

# %% [markdown]
# Let's check there are any Missing data,We will also check the type of data.

# %% [markdown]
# #### We Check First Train

# %%
def missing_data(data):
    total = data.isnull().sum()
    percent = (data.isnull().sum()/data.isnull().count()*100)
    tt = pd.concat([total,percent],axis=1,keys=['Total','Percent'])
    types = []
    for col in data.columns:
        dtype = str(data[col].dtype)
        types.append(dtype)
    tt['Types'] = types
    return(np.transpose(tt))

# %%
# %%time
missing_data(train_df)
# Out:
# Wall time: 801 ms
#         ID_code target    var_0    var_1    var_2    var_3    var_4    var_5  \
# Total         0      0        0        0        0        0        0        0
# Percent       0      0        0        0        0        0        0        0
# Types    object  int64  float64  float64  float64  float64  float64  float64
#
#            var_6    var_7  ...  var_190  var_191  var_192  var_193  var_194  \
# Total          0        0  ...        0        0        0        0        0
# Percent        0        0  ...        0        0        0        0        0
# Types    float64  float64  ...  float64  float64  float64  float64  float64
#
#          var_195  var_196  var_197  var_198  var_199
# Total          0        0        0        0        0
# Percent        0        0        0        0        0
# Types    float64  float64  float64  float64  float64
#
# [3 rows x 202 columns]

# %% [markdown]
# #### Here We Check test dataset

# %%
# %%time
missing_data(test_df)
# Out:
# Wall time: 690 ms
#         ID_code    var_0    var_1    var_2    var_3    var_4    var_5  \
# Total         0        0        0        0        0        0        0
# Percent       0        0        0        0        0        0        0
# Types    object  float64  float64  float64  float64  float64  float64
#
#            var_6    var_7    var_8  ...  var_190  var_191  var_192  var_193  \
# Total          0        0        0  ...        0        0        0        0
# Percent        0        0        0  ...        0        0        0        0
# Types    float64  float64  float64  ...  float64  float64  float64  float64
#
#          var_194  var_195  var_196  var_197  var_198  var_199
# Total          0        0        0        0        0        0
# Percent        0        0        0        0        0        0
# Types    float64  float64  float64  float64  float64  float64
#
# [3 rows x 201 columns]

# %% [markdown]
# There are No missing data in train and test datasets.Let's check the numerical values in train and test dataset

# %%
# %%time
train_df.describe()
# Out:
# Wall time: 2.64 s
#               target          var_0          var_1          var_2  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean        0.100490      10.679914      -1.627622      10.715192
# std         0.300653       3.040051       4.050044       2.640894
# min         0.000000       0.408400     -15.043400       2.117100
# 25%         0.000000       8.453850      -4.740025       8.722475
# 50%         0.000000      10.524750      -1.608050      10.580000
# 75%         0.000000      12.758200       1.358625      12.516700
# max         1.000000      20.315000      10.376800      19.353000
#
#                var_3          var_4          var_5          var_6  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean        6.796529      11.078333      -5.065317       5.408949
# std         2.043319       1.623150       7.863267       0.866607
# min        -0.040200       5.074800     -32.562600       2.347300
# 25%         5.254075       9.883175     -11.200350       4.767700
# 50%         6.825000      11.108250      -4.833150       5.385100
# 75%         8.324100      12.261125       0.924800       6.003000
# max        13.188300      16.671400      17.251600       8.447700
#
#                var_7          var_8  ...        var_190        var_191  \
# count  200000.000000  200000.000000  ...  200000.000000  200000.000000
# mean       16.545850       0.284162  ...       3.234440       7.438408
# std         3.418076       3.332634  ...       4.559922       3.023272
# min         5.349700     -10.505500  ...     -14.093300      -2.691700
# 25%        13.943800      -2.317800  ...      -0.058825       5.157400
# 50%        16.456800       0.393700  ...       3.203600       7.347750
# 75%        19.102900       2.937900  ...       6.406200       9.512525
# max        27.691800      10.151300  ...      18.440900      16.716500
#
#              var_192        var_193        var_194        var_195  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean        1.927839       3.331774      17.993784      -0.142088
# std         1.478423       3.992030       3.135162       1.429372
# min        -3.814500     -11.783400       8.694400      -5.261000
# 25%         0.889775       0.584600      15.629800      -1.170700
# 50%         1.901300       3.396350      17.957950      -0.172700
# 75%         2.949500       6.205800      20.396525       0.829600
# max         8.402400      18.281800      27.928800       4.272900
#
#              var_196        var_197        var_198        var_199
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean        2.303335       8.908158      15.870720      -3.326537
# std         5.454369       0.921625       3.010945      10.438015
# min       -14.209600       5.960600       6.299300     -38.852800
# 25%        -1.946925       8.252800      13.829700     -11.208475
# 50%         2.408900       8.888200      15.934050      -2.819550
# 75%         6.556725       9.593300      18.064725       4.836800
# max        18.321500      12.000400      26.079100      28.500700
#
# [8 rows x 201 columns]

# %%
# %%time
test_df.describe()
# Out:
# Wall time: 2.67 s
#                var_0          var_1          var_2          var_3  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean       10.658737      -1.624244      10.707452       6.788214
# std         3.036716       4.040509       2.633888       2.052724
# min         0.188700     -15.043400       2.355200      -0.022400
# 25%         8.442975      -4.700125       8.735600       5.230500
# 50%        10.513800      -1.590500      10.560700       6.822350
# 75%        12.739600       1.343400      12.495025       8.327600
# max        22.323400       9.385100      18.714100      13.142000
#
#                var_4          var_5          var_6          var_7  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean       11.076399      -5.050558       5.415164      16.529143
# std         1.616456       7.869293       0.864686       3.424482
# min         5.484400     -27.767000       2.216400       5.713700
# 25%         9.891075     -11.201400       4.772600      13.933900
# 50%        11.099750      -4.834100       5.391600      16.422700
# 75%        12.253400       0.942575       6.005800      19.094550
# max        16.037100      17.253700       8.302500      28.292800
#
#                var_8          var_9  ...        var_190        var_191  \
# count  200000.000000  200000.000000  ...  200000.000000  200000.000000
# mean        0.277135       7.569407  ...       3.189766       7.458269
# std         3.333375       1.231865  ...       4.551239       3.025189
# min        -9.956000       4.243300  ...     -14.093300      -2.407000
# 25%        -2.303900       6.623800  ...      -0.095000       5.166500
# 50%         0.372000       7.632000  ...       3.162400       7.379000
# 75%         2.930025       8.584825  ...       6.336475       9.531100
# max         9.665500      11.003600  ...      20.359000      16.716500
#
#              var_192        var_193        var_194        var_195  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean        1.925944       3.322016      17.996967      -0.133657
# std         1.479966       3.995599       3.140652       1.429678
# min        -3.340900     -11.413100       9.382800      -4.911900
# 25%         0.882975       0.587600      15.634775      -1.160700
# 50%         1.892600       3.428500      17.977600      -0.162000
# 75%         2.956000       6.174200      20.391725       0.837900
# max         8.005000      17.632600      27.947800       4.545400
#
#              var_196        var_197        var_198        var_199
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean        2.290899       8.912428      15.869184      -3.246342
# std         5.446346       0.920904       3.008717      10.398589
# min       -13.944200       6.169600       6.584000     -39.457800
# 25%        -1.948600       8.260075      13.847275     -11.124000
# 50%         2.403600       8.892800      15.943400      -2.725950
# 75%         6.519800       9.595900      18.045200       4.935400
# max        15.920700      12.275800      26.538400      27.907400
#
# [8 rows x 200 columns]

# %% [markdown]
# We can make few observations here:
#     * Standard Deviation is relatively large for both train and test variable data;
#     * Min,Max,mean,sdt values for train and test data looks quite close;
#     * Mean values are distriburted over a large number.
# The Number of values in train and test set is the same.Let's plot the scatter plot for train and test set for few of the features.

# %%
def plot_feature_scatter(df1,df2,features):
    i= 0
    sns.set_style("whitegrid")
    plt.figure()
    fig,ax = plt.subplots(4,4,figsize=(14,14))
    
    
    for feature in features:
        i += 1
        plt.subplot(4,4,i)
        plt.scatter(df1[feature],df2[feature],marker="+")
        plt.xlabel(feature,fontsize=9)
        
    plt.show();

# %% [markdown]
# We will show just 5% of the data.On x axis we show train values and on the y_axis we show the test values.

# %%
features  = ['var_0','var_1','var_2','var_3','var_4','var_5','var_6',
            'var_7','var_8','var_9','var_10','var_11','var_12','var_13','var_14','var_15']
plot_feature_scatter(train_df[::20],test_df[::20],features)

# %% [markdown]
# Let's Check the distribution of target value in train Dataset

# %%
sns.countplot(train_df['target'],palette="Set2")

# %%
print("There are {}% target values with 1".format(100*train_df['target'].value_counts()[1]/train_df.shape[0]))
# Out:
# There are 10.049% target values with 1

# %% [markdown]
# The dataset is unbalanced with respect with "Target" value.

# %% [markdown]
# ##### Density Plots of Features

# %% [markdown]
# *  Let's show now the density plot of variables in train dataset;
# * We Repersent with different colors the distribution for values target 0 and 1.

# %%
def plot_feature_distribution(df1,df2,label1,label2,features):
    i = 0
    sns.set_style("whitegrid")
    plt.figure()
    fig , ax = plt.subplots(10,10,figsize=(18,22))
    
    
    for feature in features:
        i+=1
        plt.subplot(10,10,i)
        sns.distplot(df1[feature],hist=False,label=label1)
        sns.distplot(df2[feature],hist=False,label=label2)
        plt.xlabel(feature,fontsize=9)
        locs,labels = plt.xticks()
        plt.tick_params(axis='x',which='major',labelsize=6,pad=-6)
        plt.tick_params(axis='y',which='major',labelsize=6)
        
        plt.show();

# %% [markdown]
# The Fisrt 100 values are displayed in the following cell.Press **Output**to display the plots.

# %%
t0 = train_df.loc[train_df['target']==0]
t1 = train_df.loc[train_df['target']==1]
features = train_df.columns.values[2:102]
plot_feature_distribution(t0,t1,'0','1',features)

# %% [markdown]
# The next 100 values are displayed in the following cell. Press **Output** to display the plots.

# %%
features = train_df.columns.values[102:202]
plot_feature_distribution(t0, t1, '0', '1', features)

# %% [markdown]
# We can observe that there is a considerable number of features with significant different distribution for the two target values.
# For example, var_0, var_1, var_2, var_5, var_9, var_13, var_106, var_109, var_139 and many others.
#
# Also some features, like var_2, var_13, var_26, var_55, var_175, var_184, var_196 shows a distribution that resambles to a bivariate distribution.
#
# We will take this into consideration in the future for the selection of the features for our prediction model.
#
# * Le't s now look to the distribution of the same features in parallel in train and test datasets.
#
# * The first 100 values are displayed in the following cell. Press **Output** to display the plots.

# %%
features = train_df.columns.values[2:102]
plot_feature_distribution(train_df, test_df, 'train', 'test', features)

# %% [markdown]
# #### The next 100 values are displayed in the following cell. Press **Output** to display the plots.

# %%
features = train_df.columns.values[102:202]
plot_feature_distribution(train_df, test_df, 'train', 'test', features)

# %% [markdown]
# ## The train and test seems to be well ballanced with respect with distribution of the numeric variables

# %% [markdown]
# #### Distribution of mean and Std.

# %% [markdown]
# Let's check the distribution of the mean values per row in the train and test set.

# %%
plt.figure(figsize=(16,6))
features = train_df.columns.values[2:202]
plt.title("Distribution of mean values per row in the train and test set")
sns.distplot(train_df[features].mean(axis=1),color='green',kde=True,bins=120,label='train')
sns.distplot(test_df[features].mean(axis=1),color='blue',kde=True,bins=120,label='test')
plt.legend()
plt.show()

# %% [markdown]
# Let's check the distribution of the mean values per columns in the train and test set.

# %%
plt.figure(figsize=(16,6))
plt.title("Distribution of mean values per column in the train and test set")
sns.distplot(train_df[features].mean(axis=0),color='magenta',kde=True,bins=120,label='train')
sns.distplot(test_df[features].mean(axis=0),color='darkblue',kde=True,bins=120,label='test')
plt.legend()
plt.show()

# %% [markdown]
# Let's show the distribution of standard deviation of values per row for train and test datasets.

# %%
plt.figure(figsize=(16,6))
plt.title("Distribution of std values per row in the train and test set ")
sns.distplot(train_df[features].std(axis=1),color='black',kde=True,bins=120,label="train")
sns.distplot(test_df[features].std(axis=0),color='red',kde=True,bins=120,label='test')
plt.legend()
plt.show()

# %% [markdown]
# Let's check the distribution of the standard deviation of values per columns in the train and test datasets.

# %%
plt.figure(figsize=(16,6))
plt.title("Distribution of std values per column in the train and test set")
sns.distplot(train_df[features].std(axis=0),color="blue",kde=True,bins=120, label='train')
sns.distplot(test_df[features].std(axis=0),color="green", kde=True,bins=120, label='test')
plt.legend(); plt.show()

# %% [markdown]
# Let's check now the distribution of the mean value per row in the train dataset, grouped by value of target.

# %%
t0 = train_df.loc[train_df['target'] == 0]
t1 = train_df.loc[train_df['target'] == 1]
plt.figure(figsize=(16,6))
plt.title("Distribution of mean values per row in the train set")
sns.distplot(t0[features].mean(axis=1),color="red", kde=True,bins=120, label='target = 0')
sns.distplot(t1[features].mean(axis=1),color="blue", kde=True,bins=120, label='target = 1')
plt.legend(); plt.show()

# %% [markdown]
# Let's check now the distribution of the mean value per column in the train dataset, grouped by value of target.

# %%
plt.figure(figsize=(16,6))
plt.title("Distribution of mean values per column in the train set")
sns.distplot(t0[features].mean(axis=0),color="green", kde=True,bins=120, label='target = 0')
sns.distplot(t1[features].mean(axis=0),color="darkblue", kde=True,bins=120, label='target = 1')
plt.legend(); plt.show()

# %% [markdown]
# ##### Distribution of min and Max

# %% [markdown]
# let's check the distribution of min per row in the train and test set

# %%
plt.figure(figsize=(16,6))
features = train_df.columns.values[2:202]
plt.title("Distribution of min values per row in the train and test set")
sns.distplot(train_df[features].min(axis=1),color="red", kde=True,bins=120, label='train')
sns.distplot(test_df[features].min(axis=1),color="orange", kde=True,bins=120, label='test')
plt.legend()
plt.show()

# %% [markdown]
# A long queue to the lower values for both, extended as long as to -80 for test set, is observed.
#
# Let's now show the distribution of min per column in the train and test set.

# %%
plt.figure(figsize=(16,6))
features = train_df.columns.values[2:202]
plt.title("Distribution of min values per column in the train and test set")
sns.distplot(train_df[features].min(axis=0),color="magenta", kde=True,bins=120, label='train')
sns.distplot(test_df[features].min(axis=0),color="darkblue", kde=True,bins=120, label='test')
plt.legend()
plt.show()

# %% [markdown]
# Let's check now the distribution of max values per rows for train and test set.

# %%
plt.figure(figsize=(16,6))
features = train_df.columns.values[2:202]
plt.title("Distribution of max values per row in the train and test set")
sns.distplot(train_df[features].max(axis=1),color="brown", kde=True,bins=120, label='train')
sns.distplot(test_df[features].max(axis=1),color="yellow", kde=True,bins=120, label='test')
plt.legend()
plt.show()

# %% [markdown]
# Let's show now the max distribution on columns for train and test set.

# %%
plt.figure(figsize=(16,6))
features = train_df.columns.values[2:202]
plt.title("Distribution of max values per column in the train and test set")
sns.distplot(train_df[features].max(axis=0),color="blue", kde=True,bins=120, label='train')
sns.distplot(test_df[features].max(axis=0),color="red", kde=True,bins=120, label='test')
plt.legend()
plt.show()

# %% [markdown]
# Let's show now the distributions of min values per row in train set, separated on the values of target (0 and 1).

# %%
t0 = train_df.loc[train_df['target']==1]
t1 = train_df.loc[train_df['target']==0]
plt.figure(figsize=(10,6))
plt.title("Distribution of min values per row in the train set")
sns.distplot(t0[features].min(axis=1),color='orange',kde=True,bins=100,label='target=0')
sns.distplot(t1[features].min(axis=1),color='darkblue',kde=True,bins=100,label='target=1')
plt.legend();plt.show()

# %% [markdown]
# We show here the distribution of min values per column in train set

# %%
plt.figure(figsize=(10,6))
plt.title("Distribution of min values per column in train set")
sns.distplot(t0[features].min(axis=0),color='red',bins=100,kde=True,label='target=0')
sns.distplot(t1[features].min(axis=0),color='blue',bins=100,kde=True,label='target=1')
plt.legend()
plt.show()

# %% [markdown]
# Let's show now the distribution of max values per rown in the train set

# %%
plt.figure(figsize=(10,6))
plt.title("Distribution of max values per row in the train set ")
sns.distplot(t0[features].max(axis=1),color='gold',kde=True,bins=100,label='target=0')
sns.distplot(t1[features].max(axis=1),color='darkblue',kde=True,bins=100,label='target=1')
plt.legend();plt.show()

# %% [markdown]
# Let's show also the distribution of max values per column in the train set

# %%
plt.figure(figsize=(16,6))
plt.title("Distribution of max values per column in the train set")
sns.distplot(t0[features].max(axis=0),color='red',kde=True,bins=120,label='target=0')
sns.distplot(t1[features].max(axis=0),color='blue',kde=True,bins=120,label='target=1')
plt.legend();
plt.show()

# %% [markdown]
# ### Distribution of Skew and Kurtosis

# %% [markdown]
# Let's see now what is the distribution of skew values per rows and columns

# %% [markdown]
# Let's see first the distribution of skewness calculated per rows and in train and test sets

# %%
plt.figure(figsize=(16,6))
plt.title("Distribution of skew per row in the train and test set")
sns.distplot(train_df[features].skew(axis=1),color='red',kde=True,bins=100,label='train')
sns.distplot(test_df[features].skew(axis=1),color='orange',kde=True,bins=100,label='test')
plt.legend();
plt.show()

# %% [markdown]
# Let's see first the distribution of skewness calculated per columns in train and test set.

# %%
plt.figure(figsize=(16,6))
plt.title("Distribution of skew per column in train and test set ")
sns.distplot(train_df[features].skew(axis=0),color='magenta',kde=True,bins=110,label='train')
sns.distplot(test_df[features].skew(axis=0),color='darkblue',kde=True,bins=110,label='test')
plt.legend();
plt.show()

# %% [markdown]
# Let's see now what is the distribution of kurtosis values per rows and columns

# %% [markdown]
# Let's see first the distribution of kurtosis calculated per rows in train and test

# %%
plt.figure(figsize=(16,6))
plt.title("Distribution of kurtosis per row in the train and test set")
sns.distplot(train_df[features].kurtosis(axis=1),color='darkblue',kde=True,bins=100,label='train')
sns.distplot(test_df[features].kurtosis(axis=1),color='yellow',kde=True,bins=110,label='test')
plt.legend();
plt.show()

# %% [markdown]
# Let's see the Distribution of kurtosis caluculated per columns in train and test sets

# %%
plt.figure(figsize=(19,9))
plt.title("Distribution of kurtosis per column in the train and test set ")
sns.distplot(train_df[features].kurtosis(axis=0),color='magenta',kde=True,bins=100,label='train')
sns.distplot(test_df[features].kurtosis(axis=0),color='green',kde=True,bins=100,label='test')
plt.legend();
plt.show()

# %% [markdown]
# Let's see now the distribution of skewness on rows in train separated for values of target 0 and 1.

# %%
t0 = train_df.loc[train_df['target'] == 0]
t1 = train_df.loc[train_df['target'] == 1]
plt.figure(figsize=(16,6))
plt.title("Distribution of skew values per row in the train set")
sns.distplot(t0[features].skew(axis=1),color="red", kde=True,bins=120, label='target = 0')
sns.distplot(t1[features].skew(axis=1),color="blue", kde=True,bins=120, label='target = 1')
plt.legend(); plt.show()

# %% [markdown]
# Let's see now the distribution of skewness on columns in train separated for values of target 0 and 1.

# %%
t0 = train_df.loc[train_df['target'] == 0]
t1 = train_df.loc[train_df['target'] == 1]
plt.figure(figsize=(16,6))
plt.title("Distribution of skew values per column in the train set")
sns.distplot(t0[features].skew(axis=0),color="red", kde=True,bins=120, label='target = 0')
sns.distplot(t1[features].skew(axis=0),color="blue", kde=True,bins=120, label='target = 1')
plt.legend(); plt.show()

# %% [markdown]
# Let's see now the distribution of kurtosis on rows in train separated for values of target 0 and 1.

# %%
t0 = train_df.loc[train_df['target'] == 0]
t1 = train_df.loc[train_df['target'] == 1]
plt.figure(figsize=(16,6))
plt.title("Distribution of kurtosis values per row in the train set")
sns.distplot(t0[features].kurtosis(axis=1),color="red", kde=True,bins=120, label='target = 0')
sns.distplot(t1[features].kurtosis(axis=1),color="blue", kde=True,bins=120, label='target = 1')
plt.legend(); plt.show()

# %% [markdown]
# Let's see now the distribution of kurtosis on columns in train separated for values of target 0 and 1.

# %%
t0 = train_df.loc[train_df['target'] == 0]
t1 = train_df.loc[train_df['target'] == 1]
plt.figure(figsize=(16,6))
plt.title("Distribution of kurtosis values per column in the train set")
sns.distplot(t0[features].kurtosis(axis=0),color="red", kde=True,bins=120, label='target = 0')
sns.distplot(t1[features].kurtosis(axis=0),color="blue", kde=True,bins=120, label='target = 1')
plt.legend(); plt.show()

# %% [markdown]
# ### Features correlation

# %% [markdown]
# We calculate now the correlations between the features in train set

# %% [markdown]
# The Following tables shows the first 10 the laest corelated features.

# %%
# %%time
correlations = train_df[features].corr().abs().unstack().sort_values(kind='quicksort').reset_index()
correlations = correlations[correlations['level_0']!=correlations['level_1']]
correlations.head(10)
# Out:
# Wall time: 38.5 s
#    level_0  level_1             0
# 0   var_75  var_191  2.703975e-08
# 1  var_191   var_75  2.703975e-08
# 2  var_173    var_6  5.942735e-08
# 3    var_6  var_173  5.942735e-08
# 4  var_126  var_109  1.313947e-07
# 5  var_109  var_126  1.313947e-07
# 6  var_144   var_27  1.772502e-07
# 7   var_27  var_144  1.772502e-07
# 8  var_177  var_100  3.116544e-07
# 9  var_100  var_177  3.116544e-07

# %% [markdown]
# Let's look to the top most correlated features,besides the same feature pairs.

# %%
correlations.tail(10)
# Out:
#        level_0  level_1         0
# 39790  var_183  var_189  0.009359
# 39791  var_189  var_183  0.009359
# 39792  var_174   var_81  0.009490
# 39793   var_81  var_174  0.009490
# 39794   var_81  var_165  0.009714
# 39795  var_165   var_81  0.009714
# 39796   var_53  var_148  0.009788
# 39797  var_148   var_53  0.009788
# 39798   var_26  var_139  0.009844
# 39799  var_139   var_26  0.009844

# %% [markdown]
# The correlation between the features is very small.

# %% [markdown]
# ## Duplicated Values

# %% [markdown]
# Let.s now check how many duplicated values exists per columns.

# %%
# %%time
features = train_df.columns.values[2:202]
unique_max_train =[]
unique_max_test = []
for feature in features:
    values = train_df[feature].value_counts()
    unique_max_train.append([feature,values.max(),values.idxmax()])
    values = test_df[feature].value_counts()
    unique_max_test.append([feature,values.max(),values.idxmax()])
# Out:
# Wall time: 10.3 s

# %% [markdown]
# Let's show the top 15 max of duplicated values per train set.

# %%
np.transpose((pd.DataFrame(unique_max_test,columns=['Feature','Max duplicates','Value'])).\
            sort_values(by="Max duplicates",ascending=False).head(15))
# Out:
#                    68       126      108      12      91       103      148  \
# Feature         var_68  var_126  var_108   var_12  var_91  var_103  var_148
# Max duplicates    1104      307      302      188      86       78       74
# Value           5.0197  11.5357  14.1999  13.5546  6.9939   1.4659   4.0004
#
#                     161      25      71       43       166      125      169  \
# Feature         var_161   var_25  var_71   var_43  var_166  var_125  var_169
# Max duplicates       69       60      60       58       53       53       51
# Value            5.7114  13.5965  0.5389  11.5738   2.8446  12.2189   5.8455
#
#                     133
# Feature         var_133
# Max duplicates       50
# Value            6.6873

# %% [markdown]
# Let's see also the top 15 number of duplicates values per test set.

# %%
np.transpose((pd.DataFrame(unique_max_train,columns=['Feature',"Max duplicates",'Value'])).\
            sort_values(by="Max duplicates",ascending=False).head(15))
# Out:
#                    68       108      126      12      91       103      148  \
# Feature         var_68  var_108  var_126   var_12  var_91  var_103  var_148
# Max duplicates    1084      313      305      203      66       61       59
# Value           5.0214  14.1999  11.5356  13.5545  6.9785   1.6662   4.0456
#
#                    71       161      25       125      169      166      133  \
# Feature         var_71  var_161   var_25  var_125  var_169  var_166  var_133
# Max duplicates      54       52       41       40       39       39       39
# Value           0.7031   5.7688  13.6723  12.5159   5.6941   2.7306   6.8632
#
#                     43
# Feature          var_43
# Max duplicates       39
# Value           11.4522

# %% [markdown]
# Same columns in train and test set have the same or very close number of duplicates of same or very close values. This is an interesting pattern that we might be able to use in the future.

# %% [markdown]
# ## Feature engineering

# %% [markdown]
# This section is under construction

# %% [markdown]
# Let's calculate for starting few aggregated values for the existing features.

# %%
# %%time
idx = features = train_df.columns.values[2:202]
for df in [test_df,train_df]:
    df['sum'] = df[idx].sum(axis=1)
    df['min'] = df[idx].sum(axis=1)
    df['max'] = df[idx].sum(axis=1)
    df['mean'] = df[idx].sum(axis=1)
    df['std'] = df[idx].sum(axis=1)
    df['skew'] = df[idx].sum(axis=1)
    df['kurt'] = df[idx].sum(axis=1)
    df['med'] = df[idx].sum(axis=1)
# Out:
# Wall time: 18.6 s

# %% [markdown]
# Let's check the new created features.

# %%
train_df[train_df.columns[202:]].head()
# Out:
#          sum        min        max       mean        std       skew  \
# 0  1456.3182  1456.3182  1456.3182  1456.3182  1456.3182  1456.3182
# 1  1415.3636  1415.3636  1415.3636  1415.3636  1415.3636  1415.3636
# 2  1240.8966  1240.8966  1240.8966  1240.8966  1240.8966  1240.8966
# 3  1288.2319  1288.2319  1288.2319  1288.2319  1288.2319  1288.2319
# 4  1354.2310  1354.2310  1354.2310  1354.2310  1354.2310  1354.2310
#
#         kurt        med
# 0  1456.3182  1456.3182
# 1  1415.3636  1415.3636
# 2  1240.8966  1240.8966
# 3  1288.2319  1288.2319
# 4  1354.2310  1354.2310

# %%
test_df[test_df.columns[201:]].head()
# Out:
#          sum        min        max       mean        std       skew  \
# 0  1416.6404  1416.6404  1416.6404  1416.6404  1416.6404  1416.6404
# 1  1249.6860  1249.6860  1249.6860  1249.6860  1249.6860  1249.6860
# 2  1430.2599  1430.2599  1430.2599  1430.2599  1430.2599  1430.2599
# 3  1411.4447  1411.4447  1411.4447  1411.4447  1411.4447  1411.4447
# 4  1423.7364  1423.7364  1423.7364  1423.7364  1423.7364  1423.7364
#
#         kurt        med
# 0  1416.6404  1416.6404
# 1  1249.6860  1249.6860
# 2  1430.2599  1430.2599
# 3  1411.4447  1411.4447
# 4  1423.7364  1423.7364

# %%
def plot_new_feature_distribution(df1,df2,label1,label2,features):
    i = 0
    sns.set_style('whitegrid')
    plt.figure()
    fig,ax = plt.subplots(2,4,figsize=(18,8))
    
    for feature in features:
        i += 1
        plt.subplot(2,4,i)
        sns.kdeplot(df1[feature],bw=0.5,label=label1)
        sns.kdeplot(df2[feature],bw=0.5,label=label2)
        plt.xlabel(feature,fontsize=11)
        locs,lables = plt.xticks()
        plt.tick_params(axis='x',which='major',labelsize=8)
        plt.tick_params(axis='y',which='major',labelsize=8)
    plt.show();

# %% [markdown]
# Let's check the distribution of these new, engineered features.

# %% [markdown]
# We plot first the distribution of new features, grouped by value of corresponding target values.

# %%
t0 = train_df.loc[train_df['target'] == 0]
t1 = train_df.loc[train_df['target'] == 1]
features = train_df.columns.values[202:]
plot_new_feature_distribution(t0, t1, 'target: 0', 'target: 1', features)

# %% [markdown]
# Let's show the distribution of new features values for train and test.

# %%
features = train_df.columns.values[202:]
plot_new_feature_distribution(train_df, test_df, 'train', 'test', features)

# %% [markdown]
# We add rounded features.

# %% [markdown]
# Note: this is a work in progress, some of the features added here will be later dropped.

# %%
#features = [c for c in train_df.columns if c not in ['ID_code', 'target']]
#for feature in features:
    #train_df['r2_'+feature] = np.round(train_df[feature], 2)
    #test_df['r2_'+feature] = np.round(test_df[feature], 2)
    #train_df['r1_'+feature] = np.round(train_df[feature], 1)
    #test_df['r1_'+feature] = np.round(test_df[feature], 1)

# %% [markdown]
# Let's check how many features we have now.

# %%
print('Train and test columns: {} {}'.format(len(train_df.columns), len(test_df.columns)))
# Out:
# Train and test columns: 210 209

# %% [markdown]
# ### Model:

# %% [markdown]
# From the train columns list, we drop the ID and target to form the features list.

# %%
features = [c for c in train_df.columns if c not in ['ID_code', 'target']]
target = train_df['target']

# %% [markdown]
# We define the hyperparameters for the model.

# %%
param = {
    'bagging_freq':5,
    'bagging_fraction':0.4,
    'boost_from_average':'false',
    'boost':'gbdt',
    'feature_fraction':0.05,
    'learning_rate':0.01,
    'max_depth':-1,
    'metric':'auc',
    'min_sum_hessain_in_leaf':80,
    'num_levels':13,
    'num_threads':8,
    'tree_linear':'serial',
    'objective':'binary',
    'verbosity':1
}

# %% [markdown]
# We Run the model.

# %%
folds = StratifiedKFold(n_splits=10,shuffle=False,random_state=44000)
oof = np.zeros(len(train_df))
predictions = np.zeros(len(test_df))
feature_importance_df = pd.DataFrame()


for fold_,(trn_idx,val_idx) in enumerate(folds.split(train_df.values,target.values)):
    print('Fold {}'.format(fold_))
    trn_data = lgb.Dataset(train_df.iloc[trn_idx][features],label=target.iloc[trn_idx])
    val_data = lgb.Dataset(train_df.iloc[val_idx][features],label=target.iloc[val_idx])
    
    num_round = 1000000
    clf = lgb.train(param,trn_data,num_round,valid_sets=[trn_data,val_data],verbose_eval=1000,early_stopping_rounds=3000)
    oof[val_idx]=clf.predict(train_df.iloc[val_idx][features],num_iteration=clf.best_iteration)
    
    
    fold_importance_df = pd.DataFrame()
    fold_importance_df['Feature'] = features
    fold_importance_df['importance'] = clf.feature_importance()
    fold_importance_df['fold'] = fold_+1
    feature_importance_df = pd.concat([feature_importance_df,fold_importance_df],axis=0)
    
    
    predictions+=clf.predict(test_df[features],num_iteration=clf.best_iteration)/folds.n_splits
    
print("CV score:{:<8.5f}".format(roc_auc_score(target,oof)))
# Out:
# Fold 0
# Training until validation scores don't improve for 3000 rounds
# [1000]	training's auc: 0.926255	valid_1's auc: 0.889713
# [2000]	training's auc: 0.93979	valid_1's auc: 0.894563
# [3000]	training's auc: 0.950159	valid_1's auc: 0.896811
# [4000]	training's auc: 0.959276	valid_1's auc: 0.898079
# [5000]	training's auc: 0.967179	valid_1's auc: 0.898688
# [6000]	training's auc: 0.974032	valid_1's auc: 0.89864
# [7000]	training's auc: 0.979751	valid_1's auc: 0.898439
# [8000]	training's auc: 0.984449	valid_1's auc: 0.898537
# Early stopping, best iteration is:
# [5110]	training's auc: 0.968007	valid_1's auc: 0.898886
# Fold 1
# Training until validation scores don't improve for 3000 rounds
# [1000]	training's auc: 0.926366	valid_1's auc: 0.889389
# [2000]	training's auc: 0.939761	valid_1's auc: 0.894549
# [3000]	training's auc: 0.950283	valid_1's auc: 0.896716
# [4000]	training's auc: 0.95928	valid_1's auc: 0.897435
# [5000]	training's auc: 0.967156	valid_1's auc: 0.898079
# [6000]	training's auc: 0.97391	valid_1's auc: 0.898036
# [7000]	training's auc: 0.979643	valid_1's auc: 0.898003
# [8000]	training's auc: 0.98435	valid_1's auc: 0.898031
# Early stopping, best iteration is:
# [5229]	training's auc: 0.968807	valid_1's auc: 0.898176
# Fold 2
# Training until validation scores don't improve for 3000 rounds
# [1000]	training's auc: 0.926756	valid_1's auc: 0.884087
# [2000]	training's auc: 0.940297	valid_1's auc: 0.889953
# [3000]	training's auc: 0.950703	valid_1's auc: 0.892412
# [4000]	training's auc: 0.959641	valid_1's auc: 0.893218
# [5000]	training's auc: 0.967417	valid_1's auc: 0.89395
# [6000]	training's auc: 0.97406	valid_1's auc: 0.894493
# [7000]	training's auc: 0.979638	valid_1's auc: 0.894823
# [8000]	training's auc: 0.984323	valid_1's auc: 0.894889
# [9000]	training's auc: 0.98822	valid_1's auc: 0.894606
# [10000]	training's auc: 0.991345	valid_1's auc: 0.894409
# [11000]	training's auc: 0.993747	valid_1's auc: 0.894491
# Early stopping, best iteration is:
# [8026]	training's auc: 0.984428	valid_1's auc: 0.894951
# Fold 3
# Training until validation scores don't improve for 3000 rounds
# [1000]	training's auc: 0.926185	valid_1's auc: 0.889598
# [2000]	training's auc: 0.939595	valid_1's auc: 0.894055
# [3000]	training's auc: 0.950099	valid_1's auc: 0.896201
# [4000]	training's auc: 0.959151	valid_1's auc: 0.897647
# [5000]	training's auc: 0.96703	valid_1's auc: 0.898016
# [6000]	training's auc: 0.973848	valid_1's auc: 0.89827
# [7000]	training's auc: 0.979524	valid_1's auc: 0.898316
# [8000]	training's auc: 0.984296	valid_1's auc: 0.898181
# [9000]	training's auc: 0.988164	valid_1's auc: 0.898252
# Early stopping, best iteration is:
# [6753]	training's auc: 0.978218	valid_1's auc: 0.898509
# Fold 4
# Training until validation scores don't improve for 3000 rounds
# [1000]	training's auc: 0.925976	valid_1's auc: 0.890106
# [2000]	training's auc: 0.939262	valid_1's auc: 0.894657
# [3000]	training's auc: 0.949895	valid_1's auc: 0.896641
# [4000]	training's auc: 0.958969	valid_1's auc: 0.897203
# [5000]	training's auc: 0.966915	valid_1's auc: 0.897634
# [6000]	training's auc: 0.97379	valid_1's auc: 0.897788
# [7000]	training's auc: 0.97946	valid_1's auc: 0.897563
# [8000]	training's auc: 0.984175	valid_1's auc: 0.897645
# [9000]	training's auc: 0.988019	valid_1's auc: 0.897595
# [10000]	training's auc: 0.991144	valid_1's auc: 0.897502
# Early stopping, best iteration is:
# [7500]	training's auc: 0.981959	valid_1's auc: 0.897929
# Fold 5
# Training until validation scores don't improve for 3000 rounds
# [1000]	training's auc: 0.926178	valid_1's auc: 0.893735
# [2000]	training's auc: 0.93953	valid_1's auc: 0.899405
# [3000]	training's auc: 0.950025	valid_1's auc: 0.901664
# [4000]	training's auc: 0.959142	valid_1's auc: 0.902735
# [5000]	training's auc: 0.967115	valid_1's auc: 0.903071
# [6000]	training's auc: 0.973878	valid_1's auc: 0.903124
# [7000]	training's auc: 0.979585	valid_1's auc: 0.903125
# [8000]	training's auc: 0.984313	valid_1's auc: 0.902985
# [9000]	training's auc: 0.988147	valid_1's auc: 0.902874
# Early stopping, best iteration is:
# [6071]	training's auc: 0.974305	valid_1's auc: 0.903236
# Fold 6
# Training until validation scores don't improve for 3000 rounds
# [1000]	training's auc: 0.925916	valid_1's auc: 0.890999
# [2000]	training's auc: 0.939369	valid_1's auc: 0.896131
# [3000]	training's auc: 0.950127	valid_1's auc: 0.898482
# [4000]	training's auc: 0.959214	valid_1's auc: 0.899626
# [5000]	training's auc: 0.967102	valid_1's auc: 0.90019
# [6000]	training's auc: 0.973871	valid_1's auc: 0.90025
# [7000]	training's auc: 0.979584	valid_1's auc: 0.900012
# [8000]	training's auc: 0.984299	valid_1's auc: 0.899799
# Early stopping, best iteration is:
# [5087]	training's auc: 0.967742	valid_1's auc: 0.900342
# Fold 7
# Training until validation scores don't improve for 3000 rounds
# [1000]	training's auc: 0.925818	valid_1's auc: 0.888724
# [2000]	training's auc: 0.939428	valid_1's auc: 0.894364
# [3000]	training's auc: 0.950044	valid_1's auc: 0.89729
# [4000]	training's auc: 0.959121	valid_1's auc: 0.898676
# [5000]	training's auc: 0.96702	valid_1's auc: 0.898934
# [6000]	training's auc: 0.973689	valid_1's auc: 0.899661
# [7000]	training's auc: 0.979418	valid_1's auc: 0.899386
# [8000]	training's auc: 0.984181	valid_1's auc: 0.899303
# Early stopping, best iteration is:
# [5775]	training's auc: 0.972326	valid_1's auc: 0.899793
# Fold 8
# Training until validation scores don't improve for 3000 rounds
# [1000]	training's auc: 0.925629	valid_1's auc: 0.894556
# [2000]	training's auc: 0.938886	valid_1's auc: 0.900803
# [3000]	training's auc: 0.949679	valid_1's auc: 0.903216
# [4000]	training's auc: 0.958858	valid_1's auc: 0.904141
# [5000]	training's auc: 0.966822	valid_1's auc: 0.90428
# [6000]	training's auc: 0.97364	valid_1's auc: 0.904255
# [7000]	training's auc: 0.979358	valid_1's auc: 0.904357
# Early stopping, best iteration is:
# [4636]	training's auc: 0.964091	valid_1's auc: 0.904508
# Fold 9
# Training until validation scores don't improve for 3000 rounds
# [1000]	training's auc: 0.926023	valid_1's auc: 0.889411
# [2000]	training's auc: 0.93936	valid_1's auc: 0.894873
# [3000]	training's auc: 0.950061	valid_1's auc: 0.897704
# [4000]	training's auc: 0.959248	valid_1's auc: 0.898434
# [5000]	training's auc: 0.96717	valid_1's auc: 0.899098
# [6000]	training's auc: 0.973829	valid_1's auc: 0.899259
# [7000]	training's auc: 0.979575	valid_1's auc: 0.899385
# [8000]	training's auc: 0.984355	valid_1's auc: 0.899374
# [9000]	training's auc: 0.988263	valid_1's auc: 0.899441
# [10000]	training's auc: 0.991349	valid_1's auc: 0.899551
# [11000]	training's auc: 0.993764	valid_1's auc: 0.899549
# [12000]	training's auc: 0.995587	valid_1's auc: 0.899425
# Early stopping, best iteration is:
# [9679]	training's auc: 0.990441	valid_1's auc: 0.899808
# CV score:0.89908

# %% [markdown]
# Let's Check the feature importance

# %%
cols = (feature_importance_df[['Feature','importance']]
        .groupby('Feature')
        .mean()
        .sort_values(by='importance',ascending=False)[:150].index)
best_features = feature_importance_df.loc[feature_importance_df.Feature.isin(cols)]

plt.figure(figsize=(14,28))
sns.barplot(x='importance',y='Feature',data=best_features.sort_values(by='importance',ascending=False))
plt.title("Features importance(averaged/folds)")
plt.tight_layout()
plt.savefig('FI.png')

# %%
sub_df = pd.DataFrame({"ID_code":test_df['ID_code'].values})
sub_df['target'] = predictions
sub_df.to_csv("submission.csv",index=False)
